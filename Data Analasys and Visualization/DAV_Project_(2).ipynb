# %%
# Data Scraping
import requests
from bs4 import BeautifulSoup
import pandas as pd

def scrape_wikipedia(language_code):
    url = f"https://{language_code}.wikipedia.org/wiki/Main_Page"
    headers = {
        "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/94.0.4606.81 Safari/537.36"
    }
    try:
        response = requests.get(url, headers=headers)
        response.raise_for_status()
        soup = BeautifulSoup(response.content, "html.parser")

        articles = []
        for heading in soup.find_all("p", class_=""):
            articles.append(heading.text.strip())

        # response = requests.get(url, headers=headers)
        # response.raise_for_status()
        # soup = BeautifulSoup(response.content, "html.parser")

        # for heading in soup.find_all("span", class_="mw-headline"):
        #     articles.append(heading.text.strip())

        # response = requests.get(url, headers=headers)
        # response.raise_for_status()
        # soup = BeautifulSoup(response.content, "html.parser")

        # for heading in soup.find_all("span", class_="mw-headline"):
        #     articles.append(heading.text.strip())


        return articles

    except requests.HTTPError as errh:
        print(f"HTTP Error: {errh}")
    except requests.ConnectionError as errc:
        print(f"Error Connecting: {errc}")
    except requests.Timeout as errt:
        print(f"Timeout Error: {errt}")
    except requests.RequestException as err:
        print(f"Other Error: {err}")
    return []



languages = {
    "en": "English",
    "es": "Spanish",
    "fr": "French",
    "de": "German",
    "it": "Italian",
    "nl": "Dutch",
    "pt": "Portuguese",
    "ru": "Russian",
    "ja": "Japanese",
    "zh": "Chinese",
    "ar": "Arabic",
    "hi": "Hindi",
    "ko": "Korean",
    "tr": "Turkish",
    "pl": "Polish",
    "sv": "Swedish",
    "uk": "Ukrainian",
    "cs": "Czech",
    "el": "Greek",
    "he": "Hebrew",
    "th": "Thai",
    "da": "Danish",
    "fi": "Finnish",
    "id": "Indonesian",
    "no": "Norwegian",
    "hu": "Hungarian",
    "ro": "Romanian",
    "sk": "Slovak",
    "vi": "Vietnamese",
    "bn": "Bengali",
    "sr": "Serbian",
    "hr": "Croatian",
    "ms": "Malay",
    "lt": "Lithuanian",
    "sl": "Slovenian",
    "et": "Estonian",
    "gl": "Galician",
    "ta": "Tamil",
    "ca": "Catalan",
    "ur": "Urdu",
    "eu": "Basque",
    "be": "Belarusian",
    "is": "Icelandic",
    "af": "Afrikaans",
    "sw": "Swahili",
    "am": "Amharic",
    "fa": "Persian",
    "ne": "Nepali",
    "so": "Somali",
    "ka": "Georgian",
    "la": "Latin",
    "km": "Khmer",
    "mk": "Macedonian",
    "mn": "Mongolian",
    "fy": "Western Frisian",
    "gu": "Gujarati",
    "pa": "Punjabi",
    "jv": "Javanese",
    "ceb": "Cebuano",
    "ha": "Hausa",
    "yo": "Yoruba",
    "su": "Sundanese",
    "si": "Sinhala",
    "sn": "Shona",
    "hmn": "Hmong",
    "uz": "Uzbek",
    "rw": "Kinyarwanda",
    "glg": "Galician",
    "kk": "Kazakh",
    "ku": "Kurdish",
    "tt": "Tatar",
    "ast": "Asturian",
    "qu": "Quechua",
    "tl": "Tagalog",
    "tg": "Tajik",
    "my": "Burmese",
    "or": "Odia",
    "ky": "Kyrgyz",
    "et": "Estonian",
    "lt": "Lithuanian",
    "lv": "Latvian",
    "fi": "Finnish",
    "hr": "Croatian",
    "sr": "Serbian",
    "sk": "Slovak",
    "sl": "Slovenian",
    "ms": "Malay",
    "th": "Thai",
    "vi": "Vietnamese",
    "bg": "Bulgarian",
    "ro": "Romanian",
    "tr": "Turkish",
    "is": "Icelandic",
    "hu": "Hungarian",
}


data = []
for lang_code, lang_name in languages.items():
    wiki_articles = scrape_wikipedia(lang_code)
    if wiki_articles:
        for article in wiki_articles:
            data.append({"Language": lang_name, "Text": article})

# for lang_code, lang_name in languages.items():
#     wiki_articles = scrape_wikipedia(lang_code)
#     if wiki_articles:
#         for article in wiki_articles:
#             data.append({"Language": lang_name, "Text": article})


df = pd.DataFrame(data)
df.to_csv("multilingual_wikipedia_dataset.csv", index=False)
# Out:
# Error Connecting: HTTPSConnectionPool(host='hmn.wikipedia.org', port=443): Max retries exceeded with url: /wiki/Main_Page (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x7ab46edddc60>: Failed to resolve 'hmn.wikipedia.org' ([Errno -2] Name or service not known)"))
# Error Connecting: HTTPSConnectionPool(host='glg.wikipedia.org', port=443): Max retries exceeded with url: /wiki/Main_Page (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x7ab47e0e65f0>: Failed to resolve 'glg.wikipedia.org' ([Errno -2] Name or service not known)"))

# %%
#Data Wrangling


import pandas as pd
import pandas as pd
import re
from unicodedata import normalize



aggregated_df = df.groupby('Language')['Text'].agg(lambda x: ' '.join(x)).reset_index()



aggregated_df['Text'] = aggregated_df['Text'].str.lower()


aggregated_df['Text'] = aggregated_df['Text'].apply(lambda x: re.findall(r'\b\w+\b', x))


# aggregated_df['Text'] = aggregated_df['Text'].apply(lambda x: [word for word in x if word.isalnum()])


# aggregated_df['Text'] = aggregated_df['Text'].apply(lambda x: [normalize('NFKD', word).encode('ASCII', 'ignore').decode('utf-8') for word in x])


# aggregated_df['Text'] = aggregated_df['Text'].apply(lambda x: [word for word in x if word.isalnum()])

print(aggregated_df)
# Out:
#            Language                                               Text
# 0         Afrikaans  [alter, bridge, is, n, amerikaanse, rockgroep,...
# 1           Amharic  [ወደ, ውክፔዲያ, እንኳን, ደህና, መጡ, የዕውቀት, ሥራ, በፈቃደኝነት,...
# 2            Arabic  [مشروع, موسوعة, حرة, يستطيع, الجميع, تحريرها, ...
# 3          Asturian  [llunes, 27, de, payares, 2023, afáyate, na, w...
# 4            Basque  [2023ko, azaroaren, 27a, da, eta, 423, 714, ar...
# ..              ...                                                ...
# 73             Urdu  [الناصر, صلاح, الدین, یوسف, بن, ایوب, جنہیں, ع...
# 74            Uzbek  [fan, matematika, fizika, adabiyot, geografiya...
# 75       Vietnamese  [mới, chọn, vụ, ám, sát, john, f, kennedy, hàn...
# 76  Western Frisian  [52, 548, siden, yn, it, frysk, thunderball, i...
# 77           Yoruba  [ìlànà, àwọn, ìbéèrè, wíwọ, pọ, àgbàjọ, àwọn, ...
#
# [78 rows x 2 columns]

# %%
# Data Embedding
# !pip install gensim
# Out:
# Requirement already satisfied: gensim in /usr/local/lib/python3.10/dist-packages (4.3.2)
# Requirement already satisfied: numpy>=1.18.5 in /usr/local/lib/python3.10/dist-packages (from gensim) (1.23.5)
# Requirement already satisfied: scipy>=1.7.0 in /usr/local/lib/python3.10/dist-packages (from gensim) (1.11.3)
# Requirement already satisfied: smart-open>=1.8.1 in /usr/local/lib/python3.10/dist-packages (from gensim) (6.4.0)

# %%
from gensim.models import Word2Vec
import pandas as pd
import numpy as np


word2vec_model = Word2Vec(aggregated_df['Text'], vector_size=100, window=5, min_count=1, workers=4)

def average_word_embedding(sentence):
    embeddings = [word2vec_model.wv[word] for word in sentence if word in word2vec_model.wv]
    if embeddings:
        return np.mean(embeddings, axis=0)
    else:
        return np.zeros(word2vec_model.vector_size)

aggregated_df['Word_Embedding'] = aggregated_df['Text'].apply(lambda x: average_word_embedding(x))

aggregated_df.to_csv("Dataset.csv", index=False)

# %%
print(aggregated_df)
# Out:
#        Language                                               Text  \
# 0      Asturian  [ciencies, naturales, ciencies, humanes, y, ci...
# 1        Basque  [ur, ur, esklabotza, txillardegi, ba, al, zene...
# 2    Belarusian  [артыкул, дня, ці, ведаеце, вы, што, выява, дн...
# 3     Bulgarian  [стани, редактор, на, уикипедия, статия, на, с...
# 4       Burmese  [ဝ, က, ပ, ဒ, ယ, က, က, ဆ, ပ, သည, သတင, မ, ယန, အထ...
# 5       Catalan  [casa, milà, imatge, del, dia, projecte, desta...
# 6       Cebuano           [piniling, artikulo, piniling, artikulo]
# 7       Chinese  [建立目的, 网站结构, 瀏覽器主頁, 其它, 参见, 参考资料, 外部链接, 建立目的, ...
# 8      Croatian  [ostali, projekti, neprofitne, zaklade, wikime...
# 9        Danish  [de, nyeste, fremragende, artikler, de, nyeste...
# 10        Dutch  [uitgelicht, etalage, over, wikipedia, wist, j...
# 11      English  [welcome, to, wikipedia, from, today, s, featu...
# 12      Finnish  [suositeltu, artikkeli, miten, voit, auttaa, ä...
# 13       French  [wikipédia, article, labellisé, du, jour, actu...
# 14     Galician  [artigo, destacado, sobre, galicia, tal, día, ...
# 15     Georgian  [რჩეული, სტატია, დღის, სტატია, დღის, სურათი, ს...
# 16       German  [willkommen, bei, wikipedia, artikel, des, tag...
# 17        Greek  [καλώς, ήλθατε, στη, βικιπαίδεια, επιλεγμένο, ...
# 18     Gujarati  [આ, મ, સન, ઉમદ, લ, ખ, ગ, જર, ત, ય, ન, ક, ડ, લ,...
# 19       Hebrew  [הידעת, הידעת, פורטלים, פורטלים, הציטוט, היומי...
# 20        Hindi  [व, क, प, ड, य, पर, आपक, स, व, गत, ह, न, र, व,...
# 21    Hungarian  [kiemelt, cikk, a, nap, képe, tudtad, e, aktuá...
# 22    Icelandic  [velkomin, á, wikipedíu, grein, mánaðarins, í,...
# 23   Indonesian  [artikel, pilihan, peristiwa, terkini, tahukah...
# 24      Italian  [wikipedia, cosa, posso, fare, chi, fa, wikipe...
# 25     Japanese  [選り抜き記事, 新しい記事, 新しい画像, 強化記事, 今日の一枚, 今日は何の日, 11...
# 26       Kazakh  [уикипедияға, қош, келдіңіз, эрнест, хемингуэй...
# 27  Kinyarwanda  [ifoto, y, umunsi, amakuru, arambuye, kuri, im...
# 28      Kurdish  [kurdiya, başûrî, kirmaşanî, kelhurî, feylî, ş...
# 29       Kyrgyz  [учкай, маалымат, мыкты, сүрөт, билесизби, кли...
# 30        Latin                                       [2023, 2023]
# 31      Latvian  [vai, tu, zināji, ka, aktuāls, notikums, šī, d...
# 32   Macedonian  [добре, дојдовте, на, википедија, добре, дојдо...
# 33    Mongolian  [википедиа, онцлох, өгүүлэл, дэлхий, дахинд, т...
# 34       Nepali  [व, क, प, ड, य, म, स, व, गत, छ, प, रम, ख, ल, ख...
# 35    Norwegian  [ukens, artikkel, uke, 48, dagens, skandinavis...
# 36         Odia  [ନଭ, ମ, ବର, ଜନ, ମ, ମ, ତ, ୟ, ପର, ବପର, ବ, ଣ, ପଚର...
# 37       Polish  [czy, wiesz, wydarzenia, rocznice, artykuł, na...
# 38      Punjabi  [ਚ, ਣ, ਆ, ਹ, ਇਆ, ਲ, ਖ, ਅ, ਜ, ਇਤ, ਹ, ਸ, ਵ, ਚ, 2...
# 39      Quechua                       [kusa, qillqa, kusa, qillqa]
# 40      Russian  [добро, пожаловать, в, википедию, братья, стру...
# 41      Serbian  [добро, дошли, на, википедију, геноцид, над, ј...
# 42      Sinhala  [ව, ශ, ෂ, ග, ල, ප, ය, ඔබ, ද, න, ස, ට, ය, ද, ප,...
# 43    Slovenian  [naravoslovje, družboslovje, tehnika, kultura,...
# 44      Spanish  [bienvenidos, a, wikipedia, tiburón, gneisenau...
# 45    Sundanese  [1895, alfred, nobel, ngawasiatkeun, hartana, ...
# 46      Swahili  [kamusi, elezo, ya, kiswahili, je, wajua, maka...
# 47      Tagalog  [wikipedia, napiling, artikulo, alam, ba, niny...
# 48        Tajik  [ба, википедия, хуш, омадед, ибни, сино, абуна...
# 49        Tamil  [ம, தற, பக, கக, கட, ட, ர, கள, உங, கள, க, க, த,...
# 50        Tatar  [википедиягә, рәхим, итегез, көн, рәсеме, бу, ...
# 51         Thai     [ป, ายบอกทาง, ภาษาอ, น, ป, ายบอกทาง, ภาษาอ, น]
# 52      Turkish  [vikipedi, ye, hoş, geldiniz, vikipedi, ye, ho...
# 53    Ukrainian  [ласкаво, просимо, до, вікіпедії, вибрана, ста...
# 54         Urdu  [منتخب, مضمون, خبروں, میں, کیا, آپ, جانتے, ہیں...
# 55        Uzbek  [vikipediyaga, xush, kelibsiz, vikipediyaga, x...
# 56   Vietnamese  [wikipedia, tiếng, việt, bài, viết, chọn, lọc,...
#
#                                        Word_Embedding
# 0   [-0.0010491312, 0.0027267959, -0.0006212855, -...
# 1   [-0.002770289, 0.0007177386, -0.0002727673, -0...
# 2   [3.7763995e-05, 0.0020357978, 0.003613842, -0....
# 3   [-0.0011368262, -0.00028589528, 0.00063566165,...
# 4   [-0.0003770237, 0.001908743, -0.0014361127, 2....
# 5   [-0.002333081, 0.0008478324, -0.0006065733, 0....
# 6   [-0.006805687, -0.0060962723, -0.0016472839, -...
# 7   [0.0032988207, 0.0029949152, -0.00086479133, 0...
# 8   [0.0019647544, 0.001381053, -0.0012492017, 0.0...
# 9   [0.00068198756, 0.00026346758, -0.003844166, -...
# 10  [-0.00087896065, 0.0015002128, 0.0009095723, 0...
# 11  [0.0008260408, 0.0017198299, 0.002311173, -0.0...
# 12  [-0.00030733075, 0.0015720596, 0.0006016092, 0...
# 13  [0.002292274, -0.00015681563, 0.0010417603, -0...
# 14  [0.00042655808, 0.0026997712, 0.001215308, -0....
# 15  [-9.4213276e-05, -0.0011812089, 0.0010261531, ...
# 16  [0.00086469046, 0.00017321852, 0.00086542143, ...
# 17  [-0.0015469645, 0.001019389, -0.0003234063, -0...
# 18  [-0.0011810638, 0.0006141086, -0.0006235261, 0...
# 19  [-0.0015446285, 0.001249308, -0.0007693639, 0....
# 20  [0.0008020854, 0.0006195683, -0.0011987769, -0...
# 21  [-3.334605e-05, 0.00042319263, 0.0012995551, 0...
# 22  [-0.0009563346, -0.00037201025, 5.060306e-05, ...
# 23  [-0.0017799726, 0.00076776964, -0.0024713369, ...
# 24  [-2.259362e-05, 0.00056684535, 0.000552937, 0....
# 25  [0.0023745864, 0.0037719323, 0.0011958622, -0....
# 26  [-0.00046618065, -0.0015068775, 0.002139457, 0...
# 27  [-0.00012112529, 0.0028544161, -0.00012115848,...
# 28  [0.0010761314, 0.00017868944, -0.00042258407, ...
# 29  [0.00017122383, 0.0005589525, -0.0006889472, 0...
# 30  [0.0051815, 0.007340512, 0.0062465714, -0.0096...
# 31  [-0.0025701486, 0.00073755055, 0.0021810168, -...
# 32  [-0.0025352323, -0.0018548172, 0.0027459962, -...
# 33  [-0.00018501688, 0.002872087, -0.00052011776, ...
# 34  [-1.9017583e-06, 0.0016818945, -0.0013668739, ...
# 35  [-0.0025326568, -0.00085678016, -0.00017693949...
# 36  [0.0007458253, -0.0016877261, -0.0005563466, -...
# 37  [0.00066560553, -0.0006626006, -0.0018966233, ...
# 38  [0.00039129064, -0.0010846764, 0.0024954253, -...
# 39  [-0.0027722667, 0.0012306118, -0.0010964416, 0...
# 40  [0.00024477436, 0.0016131738, 0.00069551903, -...
# 41  [-0.0017826476, 0.0011161516, 0.00092405395, -...
# 42  [-0.0032932663, 0.003092151, 0.00022738789, 0....
# 43  [0.0012474507, 0.0031909284, 0.0013452726, 0.0...
# 44  [-0.0013834368, -0.0011263692, -0.00010848565,...
# 45  [-0.0013782427, 0.0036897243, 0.0028346488, 0....
# 46  [-0.00087716227, -0.0011018537, 0.0014593696, ...
# 47  [-0.00057727756, -0.0020099296, 0.00046248696,...
# 48  [-0.001182308, -0.00010673174, 0.00070287264, ...
# 49  [0.0015306529, -0.0017013703, 0.0009884776, 0....
# 50  [-0.00073175936, -7.2349605e-05, 0.0012170352,...
# 51  [-0.0049748793, 0.0037993426, -0.000812243, -0...
# 52  [0.0024856161, 0.0039718975, -0.00725365, -0.0...
# 53  [-0.003387923, 0.0019934967, 0.0006313392, -0....
# 54  [-0.00032668698, 0.0006283503, -0.0011026922, ...
# 55  [-0.0006556065, 0.0009133766, 0.0012958864, 0....
# 56  [0.00024239339, 0.0011235812, 0.00047087172, 4...
